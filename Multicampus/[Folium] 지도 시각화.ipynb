# %%
# Total Code
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import pandas as pd 
import time
import os

chrome_options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)

# Functions 
def scr_down():
    old_height = driver.execute_script('return window.scrollY')
    while True:    
        # 한 번 스크롤 다운 
        driver.find_element(By.CSS_SELECTOR, 'body').send_keys(Keys.END)
        
        time.sleep(1)

        # 스크롤 길이 탐색
        new_height = driver.execute_script('return window.scrollY')
        print(new_height, end=' > ')
        
        if new_height == old_height:
            break
        old_height = new_height
        
    print('Scroll Down End!')
# Out:
# [WDM] - Downloading: 100%|██████████| 6.29M/6.29M [00:01<00:00, 4.11MB/s]

# %% [markdown]
# # 지도 시각화하기
# * 참고 자료 : 'http://python-visualization.github.io/folium/quickstart.html#Getting-Started'

# %%
import folium

seoul_map = folium.Map(location=[37.55, 126.88], zoom_start=12)
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# 지도 저장하기 (HTML로 저장)
seoul_map.save('seoul.map.html')

# %%
# 배율 조정 
seoul_map = folium.Map(location=[37.55, 126.88], zoom_start=20)
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# 지도 스타일 조정 

seoul_map2 = folium.Map(location=[37.55, 126.88], tiles ='Stamen Terrain', zoom_start=12)
seoul_map3 = folium.Map(location=[37.55, 126.88], tiles ='Stamen Toner', zoom_start=12)

seoul_map2.save('seoul.map2.html')
seoul_map3.save('seoul.map3.html')

# %%
seoul_map2      # Stamen Terrain
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
seoul_map3      # Stamen Toner
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import pandas as pd 
df = pd.read_excel('서울지역 대학교 위치.xlsx')
df
# Out:
#         Unnamed: 0         위도          경도
# 0     KAIST 서울캠퍼스   37.592573  127.046737
# 1            KC대학교  37.548345  126.854797
# 2     가톨릭대학교(성신교정)  37.585922  127.004328
# 3     가톨릭대학교(성의교정)  37.499623  127.006065
# 4         감리교신학대학교  37.567645  126.961610
# 5            건국대학교  37.540762  127.079343
# 6     경기대학교 서울캠퍼스   37.300485  127.035833
# 7     경희대학교 서울캠퍼스   37.596195  127.052544
# 8            고려대학교  33.847782 -117.977748
# 9            광운대학교  37.619496  127.059696
# 10           국민대학교  37.609641  126.997697
# 11         덕성여자대학교  37.651199  127.016160
# 12           동국대학교  37.557477  127.002052
# 13         동덕여자대학교  37.606320  127.041808
# 14    명지대학교 서울캠퍼스   37.580205  126.923445
# 15           삼육대학교  37.642952  127.105476
# 16    상명대학교 서울캠퍼스   37.602638  126.955252
# 17           서강대학교  37.550944  126.941002
# 18           서경대학교  37.615095  127.013111
# 19       서울과학기술대학교  37.631668  127.077481
# 20         서울교육대학교  37.489961  127.016412
# ...

# %% [markdown]
# ## 서울지역 대학교 지도 표시

# %%
import folium
import pandas as pd

df = pd.read_excel('서울지역 대학교 위치.xlsx')
df.head(5)
# Out:
#      Unnamed: 0         위도          경도
# 0  KAIST 서울캠퍼스   37.592573  127.046737
# 1         KC대학교  37.548345  126.854797
# 2  가톨릭대학교(성신교정)  37.585922  127.004328
# 3  가톨릭대학교(성의교정)  37.499623  127.006065
# 4      감리교신학대학교  37.567645  126.961610

# %%
seoul_map = folium.Map(location=[37.55, 126.88], zoom_start=12)

folium.Marker(location=[37.592573,127.046737], popup='KAIST 서울캠퍼스').add_to(seoul_map)

# %%
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
df.columns = ['학교명', '위도', '경도']
df.학교명 = '<pre>' + df['학교명'] + '</pre>'

df.head(10)
# Out:
#                        학교명         위도          경도
# 0  <pre>KAIST 서울캠퍼스 </pre>  37.592573  127.046737
# 1         <pre>KC대학교</pre>  37.548345  126.854797
# 2  <pre>가톨릭대학교(성신교정)</pre>  37.585922  127.004328
# 3  <pre>가톨릭대학교(성의교정)</pre>  37.499623  127.006065
# 4      <pre>감리교신학대학교</pre>  37.567645  126.961610
# 5         <pre>건국대학교</pre>  37.540762  127.079343
# 6  <pre>경기대학교 서울캠퍼스 </pre>  37.300485  127.035833
# 7  <pre>경희대학교 서울캠퍼스 </pre>  37.596195  127.052544
# 8         <pre>고려대학교</pre>  33.847782 -117.977748
# 9         <pre>광운대학교</pre>  37.619496  127.059696

# %%
seoul_map = folium.Map(location=[37.55, 126.98], zoom_start=12)

for lat, log, name in zip(df.위도, df.경도, df.학교명):
    folium.Marker(location=[lat, log], popup = name).add_to(seoul_map)

seoul_map
# seoul_map.save('서울지역대학교지도.html')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ## Marker 모양 변경하기

# %% [markdown]
# ### 색깔, 아이콘

# %%
seoul_map = folium.Map([37.5, 127], zoom_start=13)

for lat, log, name in zip(df.위도, df.경도, df.학교명):
    folium.Marker(location=[lat, log], 
                  icon = folium.Icon(color='red', icon='info-sign'),    # icon = 'cloud'
                  popup = name).add_to(seoul_map)

seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ### 원형

# %%
seoul_map = folium.Map([37.5, 127], zoom_start=13)

for lat, log, name in zip(df.위도, df.경도, df.학교명):
    folium.CircleMarker(location=[lat, log], 
                        radius = 10,                   # 원의 반지름 크기
                        color = 'brown',                # 둘레 색상
                        fill = True,                    # 색 채움 여부
                        fill_color = 'coral',           # 채울 색깔
                        fill_opacity = 0.5,              # 투명도
                        popup = name).add_to(seoul_map)

seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ## 지도영역 단계 구분도 (Choropleth Map)

# %%
# 라이브러리 불러오기
import pandas as pd
import folium
import json

# 경기도 인구변화 데이터를 불러와서 데이터프레임으로 변환
file_path = '경기도인구데이터.xlsx'
df = pd.read_excel(file_path, index_col='구분')
# df = pd.read_excel(file_path, index_col='구분', engine= 'openpyxl')  
df.columns = df.columns.map(str)

# 경기도 시군구 경계 정보를 가진 geo-json 파일 불러오기
geo_path = '경기도행정구역경계.json'
try:
    geo_data = json.load(open(geo_path, encoding='utf-8'))
except:
    geo_data = json.load(open(geo_path, encoding='utf-8-sig'))

# 경기도 지도 만들기
g_map = folium.Map(location=[37.5502,126.982], 
                   tiles='Stamen Terrain', zoom_start=9)

# 출력할 연도 선택 (2007 ~ 2017년 중에서 선택)
year = '2007'  

# Choropleth 클래스로 단계구분도 표시하기
folium.Choropleth(geo_data=geo_data,    # 지도 경계
                 data = df[year],      # 표시하려는 데이터
                 columns = [df.index, df[year]],  # 열 지정
                 fill_color='YlOrRd', fill_opacity=0.7, line_opacity=0.3,
                 threshold_scale=[10000, 100000, 300000, 500000, 700000],               
                 key_on='feature.properties.name',
                 ).add_to(g_map)

# 지도를 HTML 파일로 저장하기
# g_map.save('C:/data/gyonggi_population_' + year + '.html')

g_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium 
import pandas as pd 
import json 

df = pd.read_excel('경기도인구데이터.xlsx')
df.columns = df.columns.map(str)
df.head(5)
# Out:
#        구분    2007    2008    2009    2010    2011    2012    2013    2014  \
# 0  수원시장안구  287474  285803  290798  293692  290999  291757  300908  301196
# 1  수원시권선구  310553  308177  304097  306783  321176  332633  331773  339835
# 2  수원시팔달구  216945  213235  219833  216503  209772  206794  204805  203479
# 3  수원시영통구  252730  260210  258421  260557  266542  289074  310671  329718
# 4  성남시수정구  256744  248452  242161  241070  236123  233997  228167  223539
#
#      2015    2016    2017
# 0  299016  296479  293828
# 1  351053  358393  365653
# 2  199180  198515  193311
# 3  335375  340654  349836
# 4  219531  232841  236932

# %%
geo_path = '경기도행정구역경계.json'
try:
    geo_data = json.load(open(geo_path, encoding='utf-8'))
    print('encoding "utf-8" 이 사용되었습니다.')
except:
    geo_data = json.load(open(geo_path, encoding='utf-8-sig'))
    print('encoding "utf-8-sig" 이 사용되었습니다.')

geo_data
# Out:
# encoding "utf-8" 이 사용되었습니다.
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'code': 31380,
#     'name': '양평군',
#     'name_eng': 'Yangpyeong-gun',
#     'base_year': 2013},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127.56113535909492, 37.6256560539258],
#       [127.57290963929243, 37.61087369350498],
#       [127.56366973908277, 37.5842624297699],
#       [127.52226606559191, 37.5828628697518],
#       [127.50048767007603, 37.569036373178626],
#       [127.47687473909174, 37.574448241913856],
#       [127.47565866803647, 37.60512112601634],
#       [127.44699730711024, 37.64497584741164],
#       [127.4272349102434, 37.66284420898682],
#       [127.40156700708162, 37.64806970784708],
#       [127.3732642199939, 37.6453987554284],
#       [127.3542931884407, 37.6250006376975],
#       [127.34360057873045, 37.588997440929354],
#       [127.31002843450217, 37.53523876142835],
#       [127.30923294884336, 37.5135706079458],
# ...

# %%
g_map = folium.Map(location=[37.5502, 126.982],
                   tiles='Stamen Terrain',
                   zoom_start=9)

g_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
year = '2007'
folium.Choropleth(geo_data=geo_data,    # 지도 경계
                 data = df[year],      # 표시하려는 데이터
                 columns = [df.index, df[year]],  # 열 지정
                 fill_color='YlOrRd', fill_opacity=0.7, line_opacity=0.3,
                 threshold_scale=[10000, 100000, 300000, 500000, 700000],               
                 key_on='feature.properties.name',
                 ).add_to(g_map)

folium.Choropleth(geo_data = geo_data,
                  data = df[year],
                  columns = [df.index, df[year]],
                  fill_color = 'YlOrRd', fill_opacity = 0.7, line_opacity = 0.3,
                  threshold_scale = [10000, 100000, 300000, 500000, 700000],
                  key_in = 'feature.properties.name'
                  ).add_to(g_map)

g_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ## 분당선 역 위치 나타내기
# * `prefix='fa'`, https://fontawesome.com/v4/icons/
# * `prefix=glyphicon'`, https://getbootstrap.com/docs/3.3/components/

# %%
import folium 
import pandas as pd 

df = pd.read_csv('국가철도공단_분당선_역위치_20211119.csv')
df = df.dropna(how='all')               # 한 행이 모두 NA인것 제외
stations = '<pre>' + df.역명 + '</pre>'
df
# Out:
#    철도운영기관명  선명              역명          경도         위도
# 0      코레일  분당              한티  127.052873  37.496237
# 1      코레일  분당              구룡  127.058856  37.486839
# 2      코레일  분당              야탑  127.128715  37.411185
# 3      코레일  분당              구성  127.105664  37.298969
# 4      코레일  분당             개포동  127.066140  37.489116
# 5      코레일  분당           대모산입구  127.072720  37.491373
# 6      코레일  분당              정자  127.108105  37.367060
# 7      코레일  분당     기흥(백남준아트센터)  127.115936  37.275619
# 8      코레일  분당             서울숲  127.044707  37.543617
# 9      코레일  분당          압구정로데오  127.040534  37.527381
# 10     코레일  분당            강남구청  127.041280  37.517186
# 11     코레일  분당             가천대  127.126697  37.448605
# 12     코레일  분당              태평  127.127709  37.440019
# 13     코레일  분당              서현  127.123592  37.385126
# 14     코레일  분당       수내(한국잡월드)  127.114322  37.378455
# 15     코레일  분당     미금(분당서울대병원)  127.108910  37.350077
# ...

# %%
g_map = folium.Map([37.5, 127], zoom_start=10)

for name, loc, lat in zip(stations, df.경도, df.위도):
    
    folium.Marker(location = [lat, loc],
                  zoom_start = 13,
                  # icon = folium.Icon(color='orange'),
                  icon = folium.Icon(color='orange', prefix='fa', icon='train'),
                  popup = name).add_to(g_map)

g_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...
