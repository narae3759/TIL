# %% [markdown]
# # 네이버 API - 검색

# %% [markdown]
# ## 방법 1.

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request

client_id = "*******************"
client_secret = "*************"

encText = urllib.parse.quote("검색할 단어")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)

rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Wed, 12 Oct 2022 14:38:39 +0900",
# 	"total":847399,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"영어 <b>단어<\/b>로 유튜브 영상 <b>검색<\/b>해주는 유글리쉬 사용법",
# 			"link":"https:\/\/blog.naver.com\/tepet\/222697272255",
# 			"description":"있는 분야의 핵심 <b>단어<\/b>를 입력하면, 그 <b>단어<\/b>가 사용된 문장이 나와주기 때문에 발음과 주로 함께 사용되는 <b>단어<\/b>들까지 강제로 영어 공부가 된다. #영어<b>단어<\/b> #유튜브 #영상<b>검색<\/b> #유글리쉬 #사용법",
# 			"bloggername":"테펫의 폭풍퇴적물",
# 			"bloggerlink":"blog.naver.com\/tepet",
# 			"postdate":"20220411"
# 		},
# 		{
# 			"title":"딕셔너리 활용 예제 | 영어 <b>단어<\/b> <b>검색<\/b> 프로그램 만들기",
# 			"link":"https:\/\/blog.naver.com\/codethem\/222310806177",
# 			"description":"아래와 같이 <b>검색할 단어<\/b>를 입력하면, 검색한 단어의 뜻을 알려줍니다. 그리고 등록되어 있지 않은 단어는 등록되어 있지 않다는 메시지를 띄워줍니다. 함께 코드를 만들어 나가기 전에, 아래 영상을 통해 오늘... ",
# 			"bloggername":"꿈을 코딩하다 CodeThem",
# 			"bloggerlink":"blog.naver.com\/codethem",
# 			"postdate":"20210415"
# 		},
# 		{
# 			"title":"네이버 블로그 금칙어 <b>검색<\/b> 누락 조심하면 좋은 <b>단어<\/b>들 모음",
# ...

# %% [markdown]
# ## 방법 2.

# %%
# p.160 # jon http://jsonviewer.stack.hu/
import requests 
from urllib.parse import urlparse

keyword = '인공지능'
url = "https://openapi.naver.com/v1/search/blog?query=" + keyword

client_id = "********************"
client_secret = "***********"

# request = urllib.request.Request(url)
# request.add_header('X-Naver-Client-Id', client_id)
# request.add_header('X-Naver-Client-Secret', client_secret)
# response = urllib.request.urlopen(request)

headers = {'X-Naver-Client-Id' : client_id, 'X-Naver-Client-Secret' : client_secret}
response = requests.get(url, headers = headers)

# %%
type(response.text)
# Out:
# str

# %%
json_obj = response.json()
print(type(json_obj))
# Out:
# <class 'dict'>

# %%
json_obj
# Out:
# {'lastBuildDate': 'Wed, 12 Oct 2022 14:47:38 +0900',
#  'total': 1488288,
#  'start': 1,
#  'display': 10,
#  'items': [{'title': '<b>인공지능</b> 전문가 데이터라벨러 지금 시작하기',
#    'link': 'https://blog.naver.com/810118son/222892549276',
#    'description': '취업훈련으로 <b>인공지능</b> 전문가 양성 교육 카테고리였어요. 비대면 시국에 맞게 전 과정을 인강으로 할... 둘러보다가 <b>인공지능</b> 전문가 쪽으로 관심이 생겼어요. 옥황상제가 하늘에서 내려준 줄이 아니고 정부가... ',
#    'bloggername': '♡빈&훈♡',
#    'bloggerlink': 'blog.naver.com/810118son',
#    'postdate': '20221005'},
#   {'title': '국비지원교육 IT <b>인공지능</b>분야 수업 신청하기',
#    'link': 'https://blog.naver.com/tyharu/222891426455',
#    'description': '특히 한국<b>인공지능</b>협회와 코웍으로 자격증 교육과정을 제공해 더더욱 인지도가 높더라고요. 데이터... <b>인공지능</b>은 사람의 도움 없이는 데이터를 옳게 학습할 수 없다는 맹점이 있더군요. 라벨을 붙인 데이터를... ',
#    'bloggername': '⁂IT&apos;S UP To ME⁂',
#    'bloggerlink': 'blog.naver.com/tyharu',
#    'postdate': '20221004'},
#   {'title': 'AI 개념완성, <b>인공지능</b> 심화 과정까지의 AMCU 강의 특장점',
#    'link': 'https://blog.naver.com/winsweet/222893377956',
# ...

# %%
json_obj['display']
# Out:
# 10

# %%
json_obj['start']
# Out:
# 1

# %%
for item in json_obj['items']:
    print(item)
    print('-'*100)
# Out:
# {'title': '<b>인공지능</b> 전문가 데이터라벨러 지금 시작하기', 'link': 'https://blog.naver.com/810118son/222892549276', 'description': '취업훈련으로 <b>인공지능</b> 전문가 양성 교육 카테고리였어요. 비대면 시국에 맞게 전 과정을 인강으로 할... 둘러보다가 <b>인공지능</b> 전문가 쪽으로 관심이 생겼어요. 옥황상제가 하늘에서 내려준 줄이 아니고 정부가... ', 'bloggername': '♡빈&훈♡', 'bloggerlink': 'blog.naver.com/810118son', 'postdate': '20221005'}
# ----------------------------------------------------------------------------------------------------
# {'title': '국비지원교육 IT <b>인공지능</b>분야 수업 신청하기', 'link': 'https://blog.naver.com/tyharu/222891426455', 'description': '특히 한국<b>인공지능</b>협회와 코웍으로 자격증 교육과정을 제공해 더더욱 인지도가 높더라고요. 데이터... <b>인공지능</b>은 사람의 도움 없이는 데이터를 옳게 학습할 수 없다는 맹점이 있더군요. 라벨을 붙인 데이터를... ', 'bloggername': '⁂IT&apos;S UP To ME⁂', 'bloggerlink': 'blog.naver.com/tyharu', 'postdate': '20221004'}
# ----------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## 함수로 정리

# %%
import requests

def call(keyword, start):
    url = "https://openapi.naver.com/v1/search/blog?query=" + keyword + \
           "&display=100" + "&start="+str(start)   # 100개의 데이터 조회, start부터 출력
    client_id = "*****************"
    client_secret = "*********"
    
    headers = {"X-Naver-Client-Id" : client_id, "X-Naver-Client-Secret" : client_secret}
    
    response = requests.get(url=url, headers=headers)
    print(response)  # 200
    return response.json()

keyword = "인공지능"
start = 3
json_obj = call(keyword, start)
json_obj
# Out:
# <Response [200]>
# {'lastBuildDate': 'Wed, 12 Oct 2022 15:12:30 +0900',
#  'total': 1488314,
#  'start': 3,
#  'display': 100,
#  'items': [{'title': 'AI 개념완성, <b>인공지능</b> 심화 과정까지의 AMCU 강의 특장점',
#    'link': 'https://blog.naver.com/winsweet/222893377956',
#    'description': '그 당시 <b>인공지능</b>이 지금과 다른 초기 기술이어서 당연히 이세돌 9단이 이길 거라 생각했지만, 결국에는 알파고의 승리로 끝났습니다. 6년이 지난 지금 더욱 발전되었고 실생활 곳곳에서 <b>인공지능</b>이 적용된... ',
#    'bloggername': 'Play IT',
#    'bloggerlink': 'blog.naver.com/winsweet',
#    'postdate': '20221006'},
#   {'title': 'LG AI 스피커 클로바 클락 기존과 달라진 점은 (<b>인공지능</b>... ',
#    'link': 'https://blog.naver.com/ki77080/222894796854',
#    'description': 'SF 영화를 보면 <b>인공지능</b> 비서가 주인공을 위해 간밤에 있었던 주요 소식을 브리핑해주죠? 클로바도 그 기능을 지원하고 있답니다. 브리핑을 요청하면 그날 일기예보, 주요 뉴스를 들려주고, 교통 정보를... ',
#    'bloggername': '취미부자 김여사',
#    'bloggerlink': 'blog.naver.com/ki77080',
#    'postdate': '20221008'},
#   {'title': '광주<b>인공지능</b>사관학교 : AICON광주 2022',
# ...

# %%
json_obj['items'][0]['title']
# Out:
# 'AI 개념완성, <b>인공지능</b> 심화 과정까지의 AMCU 강의 특장점'

# %%
json_obj['items'][0]['link']
# Out:
# 'https://blog.naver.com/winsweet/222893377956'

# %%
json_obj['items'][0]['description']
# Out:
# '그 당시 <b>인공지능</b>이 지금과 다른 초기 기술이어서 당연히 이세돌 9단이 이길 거라 생각했지만, 결국에는 알파고의 승리로 끝났습니다. 6년이 지난 지금 더욱 발전되었고 실생활 곳곳에서 <b>인공지능</b>이 적용된... '

# %%
json_obj['items'][0]['bloggerlink']
# Out:
# 'blog.naver.com/winsweet'

# %%
json_obj['items'][0]['postdate']
# Out:
# '20221006'

# %% [markdown]
# # 네이버 API - 블로그 검색

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request

client_id = "****************"
client_secret = "***********"

encText = urllib.parse.quote("인공지능")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
url = url + '&display=50' + '&start=5' + '$sort=date'
url
# Out:
# 'https://openapi.naver.com/v1/search/blog?query=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&display=50&start=5$sort=date'

# %%
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    # print(response_body)
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Fri, 14 Oct 2022 11:23:20 +0900",
# 	"total":1490308,
# 	"start":5,
# 	"display":50,
# 	"items":[
# 		{
# 			"title":"광주<b>인공지능<\/b>사관학교 : AICON광주 2022",
# 			"link":"https:\/\/blog.naver.com\/cooldere_\/222896220913",
# 			"description":"#광주<b>인공지능<\/b>사관학교 #스마트인재개발원 #<b>인공지능<\/b>국비지원 #AICON광주 AICON 광주 2022에 다녀왔어요 @! 광주<b>인공지능<\/b>사관학교에서 단체로 소풍처럼 다녀왔답니다 !! +_+ 개인이 직접 사이트에서 신청했어요... ",
# 			"bloggername":"◆ 앙거닷컴 ◆",
# 			"bloggerlink":"blog.naver.com\/cooldere_",
# 			"postdate":"20221010"
# 		},
# 		{
# 			"title":"디지털 대전환과 <b>인공지능<\/b> 융합교육의 미래를 살펴보다!",
# 			"link":"https:\/\/blog.naver.com\/moeblog\/222880238088",
# 			"description":"‘4차 산업혁명’, ‘<b>인공지능<\/b>(AI) 시대’ 그리고 ‘디지털 리터러시’ 최근 전 세계적으로 빠짐없이... * 관련 내용 : https:\/\/blog.naver.com\/moeblog\/222678882982 (혁신을 불러일으킬 <b>인공지능<\/b>(AI)교육의 중요성) 개회사... ",
# 			"bloggername":"교육부",
# 			"bloggerlink":"blog.naver.com\/moeblog",
# 			"postdate":"20220921"
# 		},
# 		{
# ...

# %%
type(response_body)
# Out:
# bytes

# %%
type(response_body.decode('utf-8'))
# Out:
# str

# %%
# 딕셔너리로 변환하기 
import json 
json_obj = json.loads(response_body.decode('utf-8'))

# %%
type(json_obj)
# Out:
# dict

# %%
json_obj
# Out:
# {'lastBuildDate': 'Fri, 14 Oct 2022 11:23:20 +0900',
#  'total': 1490308,
#  'start': 5,
#  'display': 50,
#  'items': [{'title': '광주<b>인공지능</b>사관학교 : AICON광주 2022',
#    'link': 'https://blog.naver.com/cooldere_/222896220913',
#    'description': '#광주<b>인공지능</b>사관학교 #스마트인재개발원 #<b>인공지능</b>국비지원 #AICON광주 AICON 광주 2022에 다녀왔어요 @! 광주<b>인공지능</b>사관학교에서 단체로 소풍처럼 다녀왔답니다 !! +_+ 개인이 직접 사이트에서 신청했어요... ',
#    'bloggername': '◆ 앙거닷컴 ◆',
#    'bloggerlink': 'blog.naver.com/cooldere_',
#    'postdate': '20221010'},
#   {'title': '디지털 대전환과 <b>인공지능</b> 융합교육의 미래를 살펴보다!',
#    'link': 'https://blog.naver.com/moeblog/222880238088',
#    'description': '‘4차 산업혁명’, ‘<b>인공지능</b>(AI) 시대’ 그리고 ‘디지털 리터러시’ 최근 전 세계적으로 빠짐없이... * 관련 내용 : https://blog.naver.com/moeblog/222678882982 (혁신을 불러일으킬 <b>인공지능</b>(AI)교육의 중요성) 개회사... ',
#    'bloggername': '교육부',
#    'bloggerlink': 'blog.naver.com/moeblog',
#    'postdate': '20220921'},
#   {'title': '디지털 대전환과 <b>인공지능</b> 융합교육의 미래를 살펴보다!',
# ...

# %%
json_obj['items'][0]['title']
# Out:
# '광주<b>인공지능</b>사관학교 : AICON광주 2022'

# %%
json_obj['items'][0]['link']
# Out:
# 'https://blog.naver.com/cooldere_/222896220913'

# %% [markdown]
# # 네이버 API - 쇼핑 검색

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request

client_id = "***************"
client_secret = "**************"

encText = urllib.parse.quote("모니터")
url = "https://openapi.naver.com/v1/search/shop?query=" + encText + '&display=20' # JSON 결과
# url = "https://openapi.naver.com/v1/search/shop.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Fri, 14 Oct 2022 11:37:16 +0900",
# 	"total":4034546,
# 	"start":1,
# 	"display":20,
# 	"items":[
# 		{
# 			"title":"LG전자 24MK430H 24인치 FHD IPS 광시야각 <b>모니터<\/b>",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=13643814149",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_1364381\/13643814149.20200824151155.jpg",
# 			"lprice":"169000",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"13643814149",
# 			"productType":"1",
# 			"brand":"LG전자",
# 			"maker":"LG전자",
# 			"category1":"디지털\/가전",
# 			"category2":"모니터",
# 			"category3":"",
# 			"category4":""
# 		},
# 		{
# 			"title":"삼성전자 삼성 F27T350",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=23996451524",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_2399645\/23996451524.20210302142600.jpg",
# 			"lprice":"198900",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"23996451524",
# 			"productType":"1",
# 			"brand":"삼성",
# 			"maker":"삼성전자",
# ...

# %%
# 딕셔너리로 변환하기 
import json 
json_obj = json.loads(response_body.decode('utf-8'))

# %%
json_obj
# Out:
# {'lastBuildDate': 'Fri, 14 Oct 2022 11:37:16 +0900',
#  'total': 4034546,
#  'start': 1,
#  'display': 20,
#  'items': [{'title': 'LG전자 24MK430H 24인치 FHD IPS 광시야각 <b>모니터</b>',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=13643814149',
#    'image': 'https://shopping-phinf.pstatic.net/main_1364381/13643814149.20200824151155.jpg',
#    'lprice': '169000',
#    'hprice': '',
#    'mallName': '네이버',
#    'productId': '13643814149',
#    'productType': '1',
#    'brand': 'LG전자',
#    'maker': 'LG전자',
#    'category1': '디지털/가전',
#    'category2': '모니터',
#    'category3': '',
#    'category4': ''},
#   {'title': '삼성전자 삼성 F27T350',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=23996451524',
#    'image': 'https://shopping-phinf.pstatic.net/main_2399645/23996451524.20210302142600.jpg',
#    'lprice': '198900',
#    'hprice': '',
#    'mallName': '네이버',
#    'productId': '23996451524',
#    'productType': '1',
#    'brand': '삼성',
#    'maker': '삼성전자',
# ...

# %%
json_obj.keys()
# Out:
# dict_keys(['lastBuildDate', 'total', 'start', 'display', 'items'])

# %%
items = json_obj['items']

# %%
item_lst = []
for item in items:
    title = item['title']
    link = item['link']
    image = item['image']
    lprice = item['lprice']
    hprice = item['hprice']
    mallName = item['mallName']
    productId = item['productId']
    brand = item['brand']
    category1 = item['category1']

    item_lst.append([title, link, image, lprice, mallName, productId, brand, category1])

item_lst
# Out:
# [['LG전자 24MK430H 24인치 FHD IPS 광시야각 <b>모니터</b>',
#   'https://search.shopping.naver.com/gate.nhn?id=13643814149',
#   'https://shopping-phinf.pstatic.net/main_1364381/13643814149.20200824151155.jpg',
#   '169000',
#   '네이버',
#   '13643814149',
#   'LG전자',
#   '디지털/가전'],
#  ['삼성전자 삼성 F27T350',
#   'https://search.shopping.naver.com/gate.nhn?id=23996451524',
#   'https://shopping-phinf.pstatic.net/main_2399645/23996451524.20210302142600.jpg',
#   '198900',
#   '네이버',
#   '23996451524',
#   '삼성',
#   '디지털/가전'],
#  ['삼성전자 삼성 커브드 C27R502 베젤리스 프리싱크',
#   'https://search.shopping.naver.com/gate.nhn?id=20189888243',
#   'https://shopping-phinf.pstatic.net/main_2018988/20189888243.20220519143818.jpg',
#   '209000',
#   '네이버',
#   '20189888243',
#   '삼성',
#   '디지털/가전'],
#  ['삼성전자 삼성 F24T350',
#   'https://search.shopping.naver.com/gate.nhn?id=24007197522',
#   'https://shopping-phinf.pstatic.net/main_2400719/24007197522.20210302142445.jpg',
#   '175000',
#   '네이버',
#   '24007197522',
#   '삼성',
# ...

# %% [markdown]
# # 네이버 API - 이미지 검색

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request

client_id = "**************"
client_secret = "**************"

keyword = '고양이'
encText = urllib.parse.quote(keyword)
url = "https://openapi.naver.com/v1/search/image?query=" + encText + '&display=20' # JSON 결과
# url = "https://openapi.naver.com/v1/search/shop.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Fri, 14 Oct 2022 14:19:14 +0900",
# 	"total":6037663,
# 	"start":1,
# 	"display":20,
# 	"items":[
# 		{
# 			"title":"고양이분양 렉돌 분양, 고양이분양포털 주세요닷컴 No1261999",
# 			"link":"https:\/\/www.zooseyo.com\/dog_sale\/photo\/202209\/1664156471_99533400.jpg",
# 			"thumbnail":"https:\/\/search.pstatic.net\/sunny\/?src=https:\/\/www.zooseyo.com\/dog_sale\/photo\/202209\/1664156471_99533400.jpg&type=b150",
# 			"sizeheight":"850",
# 			"sizewidth":"850"
# 		},
# 		{
# 			"title":"고양이분양 아메리칸 숏헤어 분양, 고양이분양포털 주세요닷컴 No1261682",
# 			"link":"https:\/\/www.zooseyo.com\/dog_sale\/photo\/202209\/1663927346_39069600.jpg",
# 			"thumbnail":"https:\/\/search.pstatic.net\/sunny\/?src=https:\/\/www.zooseyo.com\/dog_sale\/photo\/202209\/1663927346_39069600.jpg&type=b150",
# 			"sizeheight":"800",
# 			"sizewidth":"1200"
# 		},
# 		{
# 			"title":"안녕하세요~고양이 한 마리 입양 하려고 하는데 정보 좀 부탁 드립니다. - 뽐뿌:동식물포럼 안녕하세요~고양이 한 마리 입양 하려고 하는데 정보 좀 부탁 드립니다.",
# ...

# %%
# 딕셔너리로 변환하기 
import json 
json_obj = json.loads(response_body.decode('utf-8'))
json_obj
# Out:
# {'lastBuildDate': 'Fri, 14 Oct 2022 14:19:14 +0900',
#  'total': 6037663,
#  'start': 1,
#  'display': 20,
#  'items': [{'title': '고양이분양 렉돌 분양, 고양이분양포털 주세요닷컴 No1261999',
#    'link': 'https://www.zooseyo.com/dog_sale/photo/202209/1664156471_99533400.jpg',
#    'thumbnail': 'https://search.pstatic.net/sunny/?src=https://www.zooseyo.com/dog_sale/photo/202209/1664156471_99533400.jpg&type=b150',
#    'sizeheight': '850',
#    'sizewidth': '850'},
#   {'title': '고양이분양 아메리칸 숏헤어 분양, 고양이분양포털 주세요닷컴 No1261682',
#    'link': 'https://www.zooseyo.com/dog_sale/photo/202209/1663927346_39069600.jpg',
#    'thumbnail': 'https://search.pstatic.net/sunny/?src=https://www.zooseyo.com/dog_sale/photo/202209/1663927346_39069600.jpg&type=b150',
#    'sizeheight': '800',
#    'sizewidth': '1200'},
#   {'title': '안녕하세요~고양이 한 마리 입양 하려고 하는데 정보 좀 부탁 드립니다. - 뽐뿌:동식물포럼 안녕하세요~고양이 한 마리 입양 하려고 하는데 정보 좀 부탁 드립니다.',
#    'link': 'https://cdn.ppomppu.co.kr/zboard/data3/2011/0104/1294126459_1291280833_work_SG1S6545.jpg',
# ...

# %%
file_path = 'NAVER_imgs/'
if not os.path.isdir(file_path):
    os.mkdir(file_path)

items = json_obj['items']
item_lst = []
for ind, item in enumerate(items):
    item_lst.append(list(item.values()))
    
    # 이미지 다운로드 받기 
    link = item['link']
    extension = link.split('.')[-1]
    if len(extension) > 4:
        extension = 'jpg'
    img_response = requests.get(link)
    
    filename = keyword + '%03d.'%(ind + 1) + extension
    if img_response.status_code == 404:
        print(f'{filename} 파일을 찾을 수 없습니다.')
    
    else:
        with open(file_path + filename, 'wb') as f:
            f.write(img_response.content)
            
            print(f'{filename} 파일을 저장했습니다.')
        
    
print(f'--{len(items)}개의 -이미지가 {file_path}에 저장되었습니다.---')
item_lst

df_img = pd.DataFrame(item_lst, columns=items[0].keys())
df_img
# Out:
# 고양이001.jpg 파일을 찾을 수 없습니다.
# 고양이002.jpg 파일을 저장했습니다.
# 고양이003.jpg 파일을 저장했습니다.
# 고양이004.JPG 파일을 찾을 수 없습니다.
# 고양이005.jpg 파일을 저장했습니다.
# 고양이006.jpg 파일을 저장했습니다.
# 고양이007.jpg 파일을 저장했습니다.
# 고양이008.jpg 파일을 저장했습니다.
# 고양이009.jpeg 파일을 저장했습니다.
# 고양이010.jpg 파일을 저장했습니다.
# 고양이011.jpg 파일을 저장했습니다.
# 고양이012.jpg 파일을 저장했습니다.
# 고양이013.jpg 파일을 저장했습니다.
# 고양이014.jpg 파일을 저장했습니다.
# 고양이015.jpg 파일을 저장했습니다.
# 고양이016.jpg 파일을 찾을 수 없습니다.
# 고양이017.jpg 파일을 저장했습니다.
# 고양이018.png 파일을 저장했습니다.
# 고양이019.jpeg 파일을 저장했습니다.
# 고양이020.jpg 파일을 찾을 수 없습니다.
# --20개의 -이미지가 NAVER_imgs/에 저장되었습니다.---
#                                                 title  \
# 0                고양이분양 렉돌 분양, 고양이분양포털 주세요닷컴 No1261999
# 1          고양이분양 아메리칸 숏헤어 분양, 고양이분양포털 주세요닷컴 No1261682
# 2   안녕하세요~고양이 한 마리 입양 하려고 하는데 정보 좀 부탁 드립니다. - 뽐뿌:동...
# 3                고양이분양 렉돌 분양, 고양이분양포털 주세요닷컴 No1261942
# 4                                      고양이사진 : 030429
# 5       고양이무료분양 한국 고양이 무료분양, 고양이무료분양포털 주세요닷컴 No381340
# ...

# %% [markdown]
# # 네이버 API - 파파고 번역

# %%
import os
import sys
import urllib.request

client_id = "****************"
client_secret = "**************"

encText = urllib.parse.quote("Nice to meet you")
data = "source=en&target=ko&text=" + encText
url = "https://openapi.naver.com/v1/papago/n2mt"

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request, data=data.encode("utf-8"))

rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {"message":{"result":{"srcLangType":"en","tarLangType":"ko","translatedText":"만나서 반가워요.","engineType":"PRETRANS","pivot":null,"dict":null,"tarDict":null},"@type":"response","@service":"naverservice.nmt.proxy","@version":"1.0.0"}}

# %%
import json 
json_obj = json.loads(response_body.decode('utf-8'))
json_obj
# Out:
# {'message': {'result': {'srcLangType': 'ko',
#    'tarLangType': 'en',
#    'translatedText': 'Nice to meet you.',
#    'engineType': 'PRETRANS',
#    'pivot': None,
#    'dict': None,
#    'tarDict': None},
#   '@type': 'response',
#   '@service': 'naverservice.nmt.proxy',
#   '@version': '1.0.0'}}

# %%
json_obj['message']['result']['translatedText']
# Out:
# 'Nice to meet you.'
