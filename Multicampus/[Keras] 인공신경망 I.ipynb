# %% [markdown]
# ## 퍼셉트론

# %%
def AND(x1, x2):
    w1, w2, theta = 0.5, 0.5, 0.7
    temp = x1 * w1 + x2 * w2 
    if temp <= theta :
        return 0 
    elif temp > theta :
        return 1

print(AND(0, 0))
print(AND(1, 0))
print(AND(0, 1))
print(AND(1, 1))
# Out:
# 0
# 0
# 0
# 1

# %%
def NAND(x1, x2):
    w1, w2, theta = -0.5, -0.5, -0.7
    temp = x1 * w1 + x2 * w2
    if temp <= theta :
        return 0
    elif temp > theta:
        return 1
       
print(NAND(0, 0))
print(NAND(1, 0))
print(NAND(0, 1))
print(NAND(1, 1))
# Out:
# 1
# 1
# 1
# 0

# %%
def OR(x1, x2):
    w1, w2, theta = 0.5, 0.5, 0.3
    temp = x1 * w1 + x2 * w2
    if temp <= theta :
        return 0
    elif temp > theta:
        return 1
       
print(OR(0, 0))
print(OR(1, 0))
print(OR(0, 1))
print(OR(1, 1))
# Out:
# 0
# 1
# 1
# 1

# %%
def AND(x1, x2):
    x = np.array([x1, x2])
    w = np.array([0.5, 0.5])
    b = -0.7 
    # tmp = np.sum(w*x) + b
    tmp = np.dot(w, x.T) + b
    if tmp <= 0:
        return 0
    else: 
        return 1
    
print(AND(0, 0))
print(AND(1, 0))
print(AND(0, 1))
print(AND(1, 1))
# Out:
# 0
# 0
# 0
# 1

# %%
def NAND(x1, x2):
    x = np.array([x1, x2])
    w = np.array([-0.5, -0.5])
    b = 0.7 
    # tmp = np.sum(w*x) + b
    tmp = np.dot(w, x.T) + b
    if tmp <= 0:
        return 0
    else: 
        return 1
    
print(NAND(0, 0))
print(NAND(1, 0))
print(NAND(0, 1))
print(NAND(1, 1))
# Out:
# 1
# 1
# 1
# 0

# %%
def OR(x1, x2):
    x = np.array([x1, x2])
    w = np.array([0.5, 0.5])
    b = -0.3
    # tmp = np.sum(w*x) + b
    tmp = np.dot(w, x.T) + b
    if tmp <= 0:
        return 0
    else: 
        return 1
    
print(OR(0, 0))
print(OR(1, 0))
print(OR(0, 1))
print(OR(1, 1))
# Out:
# 0
# 1
# 1
# 1

# %%
def XOR(x1, x2):
    s1 = NAND(x1, x2) 
    s2 = OR(x1, x2)
    y = AND(s1, s2)
    return y

print(XOR(0, 0))
print(XOR(1, 0))
print(XOR(0, 1))
print(XOR(1, 1))
# Out:
# 0
# 1
# 1
# 0

# %%
import numpy as np 
x = np.array([-1.0, 1.0, 2.0])
x
y = x > 0
y
# Out:
# array([False,  True,  True])

# %% [markdown]
# # 신경망 이해하기

# %%
import numpy as np

X = np.array([1.0, 0.5])
W1 = np.array([[0.1, 0.3, 0.5],
               [0.2, 0.4, 0.6]])
B1 = np.array([0.1, 0.2, 0.3])

print(W1.shape)
print(X.shape)
print(B1.shape)

A1 = np.dot(X, W1) + B1
print(A1)
# Out:
# (2, 3)
# (2,)
# (3,)
# [0.3 0.7 1.1]

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

Z1 = sigmoid(A1)

print(A1)
print(Z1)
# Out:
# [0.3 0.7 1.1]
# [0.57444252 0.66818777 0.75026011]

# %%
W2 = np.array([[0.1, 0.4], [0.2, 0.5], [0.3, 0.6]])
B2 = np.array([0.1, 0.2])

print(Z1.shape)
print(W2.shape)
print(B2.shape)

A2 = np.dot(Z1, W2) + B2
Z2 = sigmoid(A2)
# Out:
# (3,)
# (3, 2)
# (2,)

# %%
def identity_function(x):
    return x

W3 = np.array([[0.1, 0.3], [0.2, 0.4]])
B3 = np.array([0.1, 0.2])

A3 = np.dot(Z2, W3) + B3 
Y = identity_function(A3)
print(Y)
# Out:
# [0.31682708 0.69627909]

# %%
def init_network():
    network = {}
    network['W1'] = np.array([[0.1, 0.3, 0.5], [0.2, 0.4, 0.6]])
    network['b1'] = np.array([0.1, 0.2, 0.3])
    network['W2'] = np.array([[0.1, 0.4], [0.2, 0.5], [0.3, 0.6]])
    network['b2'] = np.array([0.1, 0.2])
    network['W3'] = np.array([[0.1, 0.3], [0.2, 0.4]])
    network['b3'] = np.array([0.1, 0.2])
    
    return network

def forward(network, x):
    W1, W2, W3 = network['W1'], network['W2'], network['W3']
    b1, b2, b3 = network['b1'], network['b2'], network['b3']
    
    a1 = np.dot(x, W1) + b1
    z1 = sigmoid(a1)
    a2 = np.dot(z1, W2) + b2
    z2 = sigmoid(a2)
    a3 = np.dot(z2, W3) + b3
    y = identity_function(a3)
    
    return y

init_network()
# Out:
# {'W1': array([[0.1, 0.3, 0.5],
#         [0.2, 0.4, 0.6]]),
#  'b1': array([0.1, 0.2, 0.3]),
#  'W2': array([[0.1, 0.4],
#         [0.2, 0.5],
#         [0.3, 0.6]]),
#  'b2': array([0.1, 0.2]),
#  'W3': array([[0.1, 0.3],
#         [0.2, 0.4]]),
#  'b3': array([0.1, 0.2])}

# %%
def softmax(a):
    exp_a = np.exp(a) 
    sum_exp_a = np.sum(exp_a)
    y = exp_a / sum_exp_a 
    
    return y

a = np.array([0.3, 2.9, 4.0])
softmax(a)
# Out:
# array([0.01821127, 0.24519181, 0.73659691])

# %%
def softmax(a):
    c = np.max(a)
    exp_a = np.exp(a-c) 
    sum_exp_a = np.sum(exp_a)
    y = exp_a / sum_exp_a 
    
    return y

a = np.array([0.3, 2.9, 4.0])
softmax(a)
# Out:
# array([0.01821127, 0.24519181, 0.73659691])

# %% [markdown]
# # Gradient 이해하기

# %%
import numpy as np 
import matplotlib.pyplot as plt 

np.float32(1e-50)

def numerical_diff(f, x):
    h = 1e-4
    return (f(x + h) - f(x - h)) / (2*h)

def function_1(x):
    return 0.01 * x ** 2 + 0.1 * x

x = np.arange(0, 20, 0.1)
y = function_1(x)
plt.plot(x, y)
plt.xlabel("x")
plt.ylabel("f(x)")
plt.show()

print(numerical_diff(function_1, x = 5))
print(numerical_diff(function_1, x = 10))
# Out:
# 0.1999999999990898
# 0.2999999999986347

# %%
import numpy as np 
import matplotlib.pyplot as plt 

def function_2(x):
    return np.sum(x**2)

def function_tmp0(x0):
    return x0**2 + 4**2

print(numerical_diff(function_tmp0, x = 3))

def function_tmp1(x1):
    return 3**2 + x1**2

print(numerical_diff(function_tmp1, x = 4))
# Out:
# 6.00000000000378
# 7.999999999999119

# %%
def numerical_gradient(f, x):
    h = 1e-4
    grad = np.zeros_like(x)
    
    for idx in range(x.size):
        tmp_val = x[idx]
        
        x[idx] = tmp_val + h 
        fxh1 = f(x)
        
        x[idx] = tmp_val - h 
        fxh2 = f(x)
        
        grad[idx] = (fxh1 - fxh2) / (2*h)
        x[idx] = tmp_val
    
    return grad 

print(numerical_gradient(function_2, np.array([3.0, 4.0])))
print(numerical_gradient(function_2, np.array([0.0, 2.0])))
print(numerical_gradient(function_2, np.array([3.0, 0.0])))
# Out:
# [6. 8.]
# [0. 4.]
# [6. 0.]

# %%
x = np.array([[1,2,3],
              [4,5,6]])
xsh = x.shape
print(x)
x = x.flatten()
print(x)
x = x.reshape(xsh)
print(x)
# Out:
# [[1 2 3]
#  [4 5 6]]
# [1 2 3 4 5 6]
# [[1 2 3]
#  [4 5 6]]

# %%
def numerical_gradient(f, x):
    h = 1e-4
    grad = np.zeros_like(x)

    for i in range(x.size):
        h_arr = np.zeros_like(x)
        h_arr[i] = h
        grad[i] = (f(x + h_arr) - f(x - h_arr)) / (2 * h)

    return grad

print(numerical_gradient(function_2, np.array([3.0, 4.0])))
print(numerical_gradient(function_2, np.array([0.0, 2.0])))
print(numerical_gradient(function_2, np.array([3.0, 0.0])))
# Out:
# [6. 8.]
# [0. 4.]
# [6. 0.]

# %%
x0 = np.arange(-3, 3, 0.1)
x1 = np.arange(-3, 3, 0.1)

x0grid, x1grid = np.meshgrid(x0, x1)

x0grid = x0grid.flatten()
x1grid = x1grid.flatten()

fgrid = x0grid**2 + x1grid**2

fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter3D(x0grid, x1grid, fgrid)
ax.set_xlabel(r'$x_0$')
ax.set_ylabel(r'$x_1$')
ax.set_zlabel(r'$f$')
plt.show()

# %%
def gradient_descent(f, init_x, lr=0.01, step_num=100):
    x = init_x 
    
    for i in range(step_num):
        grad = numerical_gradient(f, x)
        x -= lr * grad
    
    return x

init_x = np.array([-3.0, 4.0])
gradient_descent(function_2, init_x=init_x, lr=0.1, step_num=100)
# Out:
# array([-6.11110793e-10,  8.14814391e-10])

# %%
# 학습률 10
init_x = np.array([-3.0, 4.0])
gradient_descent(function_2, init_x=init_x, lr=10.0, step_num=100)
# Out:
# array([-2.58983747e+13, -1.29524862e+12])

# %%
# 학습률 1e-10
init_x = np.array([-3.0, 4.0])
gradient_descent(function_2, init_x=init_x, lr=1e-10, step_num=100)
# Out:
# array([-2.99999994,  3.99999992])

# %% [markdown]
# # 단순 신경망 구현하기

# %%
# 간단한 신경망 
import numpy as np 

def softmax(a):
    C = np.max(a)
    exp_a = np.exp(a - C)
    y = exp_a / exp_a.sum()
    
    return y

def cross_entropy_error(y, t):
    delta = 1e-7
    return -np.sum(t * np.log(y + delta))

class simpleNet():
    def __init__(self):
        self.W = np.random.randn(2, 3)
    
    def predict(self, x):
        return np.dot(x, self.W)
    
    def loss(self, x, t):
        z = self.predict(x)
        y = softmax(z)
        loss = cross_entropy_error(y, t)
        
        return loss

net = simpleNet() 
print(net.W)                           # 가중치 랜덤(2, 3)
x = np.array([0.6, 0.9])
p = net.predict(x)                     # xW
print(p)       
print(np.argmax(p))                    # 최댓값 있는 인덱스 찾기 

t = np.array([0, 0, 1])                # 정답 레이블
print(net.loss(x, t))

def numerical_gradient(f, x):
    h = 1e-4  # 0.0001
    grad = np.zeros_like(x)

    it = np.nditer(x, flags=['multi_index'], op_flags=['readwrite'])
    while not it.finished:
        idx = it.multi_index
        tmp_val = x[idx]
        x[idx] = float(tmp_val) + h
        fxh1 = f(x)  # f(x+h)

        x[idx] = tmp_val - h
        fxh2 = f(x)  # f(x-h)
        grad[idx] = (fxh1 - fxh2) / (2*h)

        x[idx] = tmp_val  # 값 복원
        it.iternext()

    return grad

# def numerical_gradient(f, x):
#     h = 1e-4
#     xshape = x.shape
#     x = x.flatten()
#     grad = np.zeros_like
    
#     for i in range(x.size):
#         h_arr = np.zeros_like(x)
#         h_arr[i] = h
#         grad[i] = (f(x + h_arr) - f(x - h_arr)) / (2 * h)

#     grad = grad.reshape(xshape)
    
#     return grad

def f(W):
    return net.loss(x, t)

numerical_gradient(f, net.W)
# Out:
# [[-0.13090262  0.51328489  1.21138008]
#  [-0.08677742 -1.92690366 -0.87239933]]
# [-0.15664125 -1.42624236 -0.05833135]
# 2
# 0.770573784123274
# array([[ 0.25165159,  0.07069992, -0.32235151],
#        [ 0.37747738,  0.10604988, -0.48352726]])

# %% [markdown]
# # 신경망 구현하기

# %%
# coding: utf-8


class MulLayer:
    def __init__(self):
        self.x = None
        self.y = None

    def forward(self, x, y):
        self.x = x
        self.y = y                
        out = x * y

        return out

    def backward(self, dout):
        dx = dout * self.y  # x와 y를 바꾼다.
        dy = dout * self.x

        return dx, dy


class AddLayer:
    def __init__(self):
        pass

    def forward(self, x, y):
        out = x + y

        return out

    def backward(self, dout):
        dx = dout * 1
        dy = dout * 1

        return dx, dy

# %%
apple = 100
apple_num = 2
tax = 1.1

mul_apple_layer = MulLayer()
mul_tax_layer = MulLayer()

# forward
apple_price = mul_apple_layer.forward(apple, apple_num)
price = mul_tax_layer.forward(apple_price, tax)

# backward
dprice = 1
dapple_price, dtax = mul_tax_layer.backward(dprice)
dapple, dapple_num = mul_apple_layer.backward(dapple_price)

print("price:", int(price))
print("dApple:", dapple)
print("dApple_num:", int(dapple_num))
print("dTax:", dtax)
# Out:
# price: 220
# dApple: 2.2
# dApple_num: 110
# dTax: 200

# %%
apple = 100
apple_num = 2
orange = 150
orange_num = 3
tax = 1.1

# layer
mul_apple_layer = MulLayer()
mul_orange_layer = MulLayer()
add_apple_orange_layer = AddLayer()
mul_tax_layer = MulLayer()

# forward
apple_price = mul_apple_layer.forward(apple, apple_num)  # (1)
orange_price = mul_orange_layer.forward(orange, orange_num)  # (2)
all_price = add_apple_orange_layer.forward(apple_price, orange_price)  # (3)
price = mul_tax_layer.forward(all_price, tax)  # (4)

# backward
dprice = 1
dall_price, dtax = mul_tax_layer.backward(dprice)  # (4)
dapple_price, dorange_price = add_apple_orange_layer.backward(dall_price)  # (3)
dorange, dorange_num = mul_orange_layer.backward(dorange_price)  # (2)
dapple, dapple_num = mul_apple_layer.backward(dapple_price)  # (1)

print("price:", int(price))
print("dApple:", dapple)
print("dApple_num:", int(dapple_num))
print("dOrange:", dorange)
print("dOrange_num:", int(dorange_num))
print("dTax:", dtax)
# Out:
# <class 'float'>
# price: 715
# dApple: 2.2
# dApple_num: 110
# dOrange: 3.3000000000000003
# dOrange_num: 165
# dTax: 650
